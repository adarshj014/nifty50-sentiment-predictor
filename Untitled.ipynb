# %%
import psycopg2

conn = psycopg2.connect(
    host     = "aws-1-ap-south-1.pooler.supabase.com",
    port     = "6543",
    database = "postgres",
    user     = "postgres.czuhnjqvryexnfvzmfaq",
    password = "FfyiG8lacMA4kL3o",
    sslmode  = "require"
)
print("Connected successfully.")
conn.close()
# Out:
# Connected successfully.

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine, text

local = create_engine(
    "postgresql+psycopg2://postgres:Serotonin#14@localhost/stock_sentiment_db"
)

remote = create_engine(
    "postgresql+psycopg2://postgres.czuhnjqvryexnfvzmfaq:StockSentiment123@aws-1-ap-south-1.pooler.supabase.com:6543/postgres",
    connect_args={"sslmode": "require"}
)

for table in ['stock_prices', 'news_articles', 'daily_sentiment']:
    print(f"Migrating {table}...")
    
    with local.connect() as conn:
        df = pd.read_sql(text(f"SELECT * FROM {table}"), conn)
    
    print(f"  Read {len(df):,} rows")
    
    with remote.connect() as conn:
        df.to_sql(table, conn, if_exists='replace',
                  index=False, chunksize=500)
        conn.commit()
    
    print(f"  Done.\n")

print("All tables migrated.")
# Out:
# Migrating stock_prices...
# C:\Users\acer\AppData\Local\Temp\ipykernel_18116\901899123.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(text(f"SELECT * FROM {table}"), conn)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 18
#      15 print(f"Migrating {table}...")
#      17 with local.connect() as conn:
# ---> 18     df = pd.read_sql(text(f"SELECT * FROM {table}"), conn)
#      20 print(f"  Read {len(df):,} rows")
#      22 with remote.connect() as conn:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:702, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     700 with pandasSQL_builder(con) as pandas_sql:
# ...
